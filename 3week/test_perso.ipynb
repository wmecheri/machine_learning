# %%
import numpy as np
import pandas as pd

# %%
pd.DataFrame([10, 3000, -4000, np.inf, -np.inf])
# Out:
#         0
# 0    10.0
# 1  3000.0
# 2 -4000.0
# 3     inf
# 4    -inf

# %%
pd.DataFrame([[10, 3000, -4000, np.inf, -np.inf],[10,11,12,13,14]])
# Out:
#     0     1     2     3     4
# 0  10  3000 -4000   inf  -inf
# 1  10    11    12  13.0  14.0

# %%
df = pd.DataFrame({'X': [788, 596], 'Y': [849, 489]})
df
# Out:
#      X    Y
# 0  788  849
# 1  596  489

# %%
#df = df.drop(df.index[[2, 4]]).reset_index(drop=True)
#df

# %%
s1 = pd.Series([100, 200])
s2 = pd.Series([10, 20])
df = pd.concat([s1, s2], axis=0)
df
# Out:
# 0    100
# 1    200
# 0     10
# 1     20
# dtype: int64

# %%
df = pd.DataFrame({'Age': [1,2,23,32,65,81,84,90]})

df["AgeCategory"] = pd.cut(df["Age"], [0,20,40,60,80]) # useful with large database, we have to categorize continuous data
df
# Out:
#    Age   AgeCategory
# 0    1   (0.0, 20.0]
# 1    2   (0.0, 20.0]
# 2   23  (20.0, 40.0]
# 3   32  (20.0, 40.0]
# 4   65  (60.0, 80.0]
# 5   81           NaN
# 6   84           NaN
# 7   90           NaN

# %%
df = pd.DataFrame({'A':[2,3,5], 'Z':[4,5,6]},
index=['Uw', 'A', 'Ur'])
print(df)
# Out:
#     A  Z
# Uw  2  4
# A   3  5
# Ur  5  6

# %%
s1 = pd.Series(['100', '200', 'python',
'300.12', '400'])
s2 = pd.Series(['10', '20', 'php', '30.12', '40'])
df = pd.concat([s1, s2], axis=1)
print(df)
# Out:
#         0      1
# 0     100     10
# 1     200     20
# 2  python    php
# 3  300.12  30.12
# 4     400     40

# %%
import os
os.getcwd()

df = pd.read_csv('Cancer_Data.csv')
df.head() #df.head() df.tail() df.yenapleinmdrr
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
df['NewSalary'] = df['radius_mean'] * 10 # add a column
df.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
df.drop(df.index[[2,4]], inplace=True) # inplace = x=... it keeps the changes in the dataframe
df.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 5    843786         M        12.45         15.70           82.57      477.1
# 6    844359         M        18.25         19.98          119.60     1040.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 3          0.14250           0.28390          0.2414              0.10520
# 5          0.12780           0.17000          0.1578              0.08089
# 6          0.09463           0.10900          0.1127              0.07400
#
# ...

# %%
part_70 = df.sample(frac=0.7, random_state=10)
part_30 = df.drop(part_70.index)

# %%
part_70.head()
# Out:
#             id diagnosis  radius_mean  texture_mean  perimeter_mean  \
# 219   88119002         M        19.53         32.47          128.00
# 388     903011         B        11.27         15.50           73.38
# 461  911296202         M        27.42         26.27          186.90
# 251   88518501         B        11.50         18.45           73.28
# 80      861103         B        11.45         20.97           73.81
#
#      area_mean  smoothness_mean  compactness_mean  concavity_mean  \
# 219     1223.0          0.08420           0.11300         0.11450
# 388      392.0          0.08365           0.11140         0.10070
# 461     2501.0          0.10840           0.19880         0.36350
# 251      407.4          0.09345           0.05991         0.02638
# 80       401.5          0.11020           0.09362         0.04591
#
#      concave points_mean  ...  perimeter_worst  area_worst  smoothness_worst  \
# 219              0.06637  ...           180.20      2477.0            0.1408
# ...

# %%
print("Row 0 Column 2: ", df.iloc[0,2])
# Out:
# Row 0 Column 2:  17.99

# %%
print(df.loc[df['id'] == 903011])
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 388  903011         B        11.27          15.5           73.38      392.0
#
#      smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 388          0.08365            0.1114          0.1007              0.02757
#
#      ...  perimeter_worst  area_worst  smoothness_worst  compactness_worst  \
# 388  ...            79.73       450.0            0.1102             0.2809
#
#      concavity_worst  concave points_worst  symmetry_worst  \
# 388           0.3021               0.08272          0.2157
#
#      fractal_dimension_worst  Unnamed: 32  NewSalary
# 388                   0.1043          NaN      112.7
#
# [1 rows x 34 columns]

# %%
df.drop(['diagnosis'], axis=1, inplace=True)
df.head()
# Out:
#          id  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302        17.99         10.38          122.80     1001.0
# 1    842517        20.57         17.77          132.90     1326.0
# 3  84348301        11.42         20.38           77.58      386.1
# 5    843786        12.45         15.70           82.57      477.1
# 6    844359        18.25         19.98          119.60     1040.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 3          0.14250           0.28390          0.2414              0.10520
# 5          0.12780           0.17000          0.1578              0.08089
# 6          0.09463           0.10900          0.1127              0.07400
#
#    symmetry_mean  ...  perimeter_worst  area_worst  smoothness_worst  \
# ...

# %%
corr = df[['radius_mean', 'texture_mean', 'perimeter_mean']].corr()
corr
# Out:
#                 radius_mean  texture_mean  perimeter_mean
# radius_mean        1.000000      0.328119        0.997835
# texture_mean       0.328119      1.000000        0.333986
# perimeter_mean     0.997835      0.333986        1.000000

# %%
import matplotlib as mlp
corr.plot()
# Out:
# <Axes: >

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots()
im = ax.imshow(corr)

# %%
part_70.describe()
# Out:
#                  id  radius_mean  texture_mean  perimeter_mean    area_mean  \
# count  3.970000e+02   397.000000    397.000000      397.000000   397.000000
# mean   3.227324e+07    14.178202     19.464987       92.364332   659.948111
# std    1.343079e+08     3.543275      4.324004       24.483900   354.662639
# min    8.670000e+03     6.981000      9.710000       43.790000   143.500000
# 25%    8.689990e+05    11.700000     16.410000       75.270000   420.500000
# 50%    9.043020e+05    13.480000     19.110000       87.210000   561.300000
# 75%    8.812816e+06    16.110000     21.910000      105.100000   803.100000
# max    9.113205e+08    28.110000     33.810000      188.500000  2501.000000
#
#        smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# count       397.000000        397.000000      397.000000           397.000000
# mean          0.096080          0.105281        0.090966             0.048858
# ...

# %%
part_30.describe()
# Out:
#                  id  radius_mean  texture_mean  perimeter_mean    area_mean  \
# count  1.700000e+02   170.000000    170.000000      170.000000   170.000000
# mean   2.529669e+07    13.939429     18.897765       90.568471   636.073529
# std    1.009715e+08     3.445515      4.238949       23.619437   341.844711
# min    8.913000e+03     7.691000     10.940000       48.340000   170.400000
# 25%    8.700488e+05    11.680000     15.917500       74.720000   417.225000
# 50%    9.113995e+05    13.155000     18.320000       85.080000   530.450000
# 75%    8.910665e+06    15.357500     21.447500      102.075000   724.475000
# max    9.113205e+08    27.220000     39.280000      182.100000  2250.000000
#
#        smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# count       170.000000        170.000000      170.000000           170.000000
# mean          0.096914          0.101653        0.082458             0.048271
# ...
